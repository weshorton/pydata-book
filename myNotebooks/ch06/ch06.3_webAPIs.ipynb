# %% [markdown]
# # 6.3 Interacting with Web APIs
#
# Many websites have public APIs providing data feeds via JSON (or other format).
#
# The `requests` package is a recommended method (must install with conda)

# %%
import requests
import pandas as pd

# %% [markdown]
# Example - find the last 30 GitHub issues for pandas using the `get` function

# %%
# Set url
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# Get results
resp = requests.get(url)

# Use raise_for_status() to check for HTTP errors
resp.raise_for_status()
resp
# Out:
# <Response [200]>

# %% [markdown]
# Use the `json` method to get a python object out of the deal. Whether it's a dictionary or a list depends on what JSON is returned by `get`

# %%
data = resp.json()
print(type(data))
print(len(data))
# Out:
# <class 'list'>
# 30

# %% [markdown]
# Looks like we got a list of 30. What class is the first entry?

# %%
print(type(data[0]))
print(len(data[0]))
# Out:
# <class 'dict'>
# 30

# %% [markdown]
# It's a dictionary. What are they keys?

# %%
data[0].keys()
# Out:
# dict_keys(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason'])

# %% [markdown]
# View the title of the first one

# %%
data[0]["title"]
# Out:
# 'TST (string): more targeted xfails in test_string.py'

# %% [markdown]
# Since `data` is a list of dictionaries, we can load it into a pandas DataFrame!

# %%
# Load whole thing
issues1 = pd.DataFrame(data)
issues1.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/59703  2503884155
# 1    https://github.com/pandas-dev/pandas/pull/59702  2503847200
# 2    https://github.com/pandas-dev/pandas/pull/59700  2503675229
# 3    https://github.com/pandas-dev/pandas/pull/59699  2503648553
# 4  https://github.com/pandas-dev/pandas/issues/59698  2503534390
#
#                node_id  number  \
# 0  PR_kwDOAA0YD856UVox   59703
# 1  PR_kwDOAA0YD856UNbl   59702
# 2  PR_kwDOAA0YD856TnkJ   59700
# 3  PR_kwDOAA0YD856Thoe   59699
# 4   I_kwDOAA0YD86VOOc2   59698
#
#                                                title  ... closed_at  \
# 0  TST (string): more targeted xfails in test_str...  ...      None
# 1                      TST (string): copy/view tests  ...      None
# 2                                           Changes1  ...      None
# 3                                 Changed to GroupBy  ...      None
# 4  DOC: fix docstring validation errors for panda...  ...      None
#
#   author_association active_lock_reason  draft  \
# 0             MEMBER               None  False
# 1             MEMBER               None  False
# 2               NONE               None  False
# 3               NONE               None  False
# 4        CONTRIBUTOR               None    NaN
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                NaN
#
#                                                 body  \
# 0  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 1  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 2  - [ ] closes #59693 \r\n- [ ] [Tests added and...
# 3  - [ ] closes #59695  (Replace xxxx with the Gi...
# 4  follow up on issues https://github.com/pandas-...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/pandas-dev/pandas...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...                     None
# 2  https://api.github.com/repos/pandas-dev/pandas...                     None
# 3  https://api.github.com/repos/pandas-dev/pandas...                     None
# 4  https://api.github.com/repos/pandas-dev/pandas...                     None
#
#   state_reason
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#
# [5 rows x 30 columns]

# %%
# Load just a few fields
issues2 = pd.DataFrame(data, columns=["number", "title", "labels", "state"])
issues2
# Out:
#     number                                              title  \
# 0    59703  TST (string): more targeted xfails in test_str...
# 1    59702                      TST (string): copy/view tests
# 2    59700                                           Changes1
# 3    59699                                 Changed to GroupBy
# 4    59698  DOC: fix docstring validation errors for panda...
# 5    59697  BUG: DataFrame.stack does not work when column...
# 6    59696  ENH: add basic DataFrame.from_arrow class meth...
# 7    59695  DOC: methods in see also section in the pandas...
# 8    59694  BUG: memory leak when using read_csv with pyth...
# 9    59693  DOC: broken link for governance in the team we...
# 10   59692                                              BUG:
# 11   59690  ENH: make pandas.DataFrame.info() method able ...
# 12   59689                    DOC: Windows build instructions
# 13   59688            Fix docstring timestamps (Issue #59458)
# 14   59686  TST (string dtype): resolve all infer_string T...
# 15   59685  String dtype: map builtin str alias to StringD...
# 16   59684    BUG: fsspec URL chaining support is not working
# 17   59683  fix: use fastpath for PyCapsule export when st...
# 18   59682          String dtype: implement _get_common_dtype
# 19   59671      DOC: Clarify existence Series.dt.to_timestamp
# 20   59670  DOC: Document that DataFrame.from_records()'s ...
# 21   59666  BUG: rolling with method='table' and apply sor...
# 22   59664                                           RLS: 2.3
# 23   59659                   ENH: increase verbosity on error
# 24   59657  PERF: Melt 2x slower when future.infer_string ...
# 25   59656  BUG: arithmetic between datetime.timedelta sca...
# 26   59655  DOCS: fix docstring validation error for panda...
# 27   59654  expose `to_pandas_kwargs` in `read_parquet` wi...
# 28   59653  BUG: some cases of binary arithmetic between s...
# 29   59652  BUG: Pearson correlation outside expected rang...
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# 2                                                  []  open
# 3   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 4   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 5   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 6   [{'id': 3303158446, 'node_id': 'MDU6TGFiZWwzMz...  open
# 7   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 8   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 10  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 11  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 12  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 13                                                 []  open
# 14  [{'id': 57522093, 'node_id': 'MDU6TGFiZWw1NzUy...  open
# 15  [{'id': 57522093, 'node_id': 'MDU6TGFiZWw1NzUy...  open
# 16  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 17  [{'id': 3303158446, 'node_id': 'MDU6TGFiZWwzMz...  open
# 18  [{'id': 57522093, 'node_id': 'MDU6TGFiZWw1NzUy...  open
# 19  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 20  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 22  [{'id': 131473665, 'node_id': 'MDU6TGFiZWwxMzE...  open
# 23  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 24  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 25  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 26                                                 []  open
# 27                                                 []  open
# 28  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
